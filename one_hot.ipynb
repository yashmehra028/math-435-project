# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('other_files/CleanedDataV2.csv')
df.head()
# Out:
#       NBHD                PID                    Situs PrpCls  PrUse  CDU  \
# 0  7HST242  09-13-434-003-000        2525   RIDGE RD       R1      1    4
# 1  7HSE361  16-11-404-012-000         5330 S 93RD PL       R1      1    4
# 2  7HSE361  16-11-404-013-000         5410 S 93RD PL       R1      1    4
# 3  7AEA310  23-31-416-001-000  11737   SEABISCUIT LN       R1     12    4
# 4  7HST242  09-13-402-005-000        2421   RIDGE RD       R1      1    5
#
#    Qual  YrRD Remd Imp  ...  HSA_Acres  HSALandValue  TotAcres  V/I  \
# 0     6    NR   NR  R2  ...        NaN           NaN      1.30    I
# 1     6    NR   NR  RA  ...        NaN           NaN      0.78    I
# 2     5    NR   NR  RA  ...        NaN           NaN      0.73    I
# 3     5    NR   NR  RA  ...       2.03       12180.0      3.03    I
# 4     5  2022    6  RA  ...        NaN           NaN      0.58    I
#
#         Inst#    SaleDate  SaleQuarter  SaleYear      Price  SaleValidity
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35107 entries, 0 to 35106
# Data columns (total 36 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   NBHD          35107 non-null  object
#  1   PID           35107 non-null  object
#  2   Situs         35107 non-null  object
#  3   PrpCls        35107 non-null  object
#  4   PrUse         35107 non-null  int64
#  5   CDU           35107 non-null  int64
#  6   Qual          35107 non-null  int64
#  7   YrRD          35107 non-null  object
#  8   Remd          35107 non-null  object
#  9   Imp           35107 non-null  object
#  10  TLA           35107 non-null  int64
#  11  YrBlt         35107 non-null  int64
#  12  GarCap        35107 non-null  int64
#  13  Bedrm         35106 non-null  float64
#  14  FND           35102 non-null  float64
#  15  801Units      35107 non-null  int64
#  16  802Units      35107 non-null  int64
#  17  803Units      35107 non-null  int64
# ...

# %%
num_df = df.select_dtypes(include=np.number)

# %%
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35107 entries, 0 to 35106
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PrUse         35107 non-null  int64
#  1   CDU           35107 non-null  int64
#  2   Qual          35107 non-null  int64
#  3   TLA           35107 non-null  int64
#  4   YrBlt         35107 non-null  int64
#  5   GarCap        35107 non-null  int64
#  6   Bedrm         35106 non-null  float64
#  7   FND           35102 non-null  float64
#  8   801Units      35107 non-null  int64
#  9   802Units      35107 non-null  int64
#  10  803Units      35107 non-null  int64
#  11  FP            35107 non-null  int64
#  12  FixCt         35107 non-null  int64
#  13  Pool          35107 non-null  int64
#  14  Acres         1227 non-null   float64
#  15  LandValue     35107 non-null  int64
#  16  HSA_Acres     969 non-null    float64
#  17  HSALandValue  968 non-null    float64
# ...

# %%
print(num_df.columns)
# Out:
# Index(['PrUse', 'CDU', 'Qual', 'TLA', 'YrBlt', 'GarCap', 'Bedrm', 'FND',
#        '801Units', '802Units', '803Units', 'FP', 'FixCt', 'Pool', 'Acres',
#        'LandValue', 'HSA_Acres', 'HSALandValue', 'TotAcres', 'Inst#',
#        'SaleQuarter', 'SaleYear', 'Price', 'SaleValidity'],
#       dtype='object')

# %%
num_df.drop(columns=['Acres','HSA_Acres','HSALandValue'],inplace=True)
# Out:
# c:\Users\ymehr\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
num_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35107 entries, 0 to 35106
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PrUse         35107 non-null  int64
#  1   CDU           35107 non-null  int64
#  2   Qual          35107 non-null  int64
#  3   TLA           35107 non-null  int64
#  4   YrBlt         35107 non-null  int64
#  5   GarCap        35107 non-null  int64
#  6   Bedrm         35106 non-null  float64
#  7   FND           35102 non-null  float64
#  8   801Units      35107 non-null  int64
#  9   802Units      35107 non-null  int64
#  10  803Units      35107 non-null  int64
#  11  FP            35107 non-null  int64
#  12  FixCt         35107 non-null  int64
#  13  Pool          35107 non-null  int64
#  14  LandValue     35107 non-null  int64
#  15  TotAcres      34331 non-null  float64
#  16  Inst#         35107 non-null  int64
#  17  SaleQuarter   35107 non-null  int64
# ...

# %%
str_df = df.select_dtypes(include='object')
str_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35107 entries, 0 to 35106
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NBHD      35107 non-null  object
#  1   PID       35107 non-null  object
#  2   Situs     35107 non-null  object
#  3   PrpCls    35107 non-null  object
#  4   YrRD      35107 non-null  object
#  5   Remd      35107 non-null  object
#  6   Imp       35107 non-null  object
#  7   LandType  35107 non-null  object
#  8   Infl1     35107 non-null  object
#  9   Infl2     35107 non-null  object
#  10  V/I       35102 non-null  object
#  11  SaleDate  35107 non-null  object
# dtypes: object(12)
# memory usage: 3.2+ MB

# %%
str_df.head()
# Out:
#       NBHD                PID                    Situs PrpCls  YrRD Remd Imp  \
# 0  7HST242  09-13-434-003-000        2525   RIDGE RD       R1    NR   NR  R2
# 1  7HSE361  16-11-404-012-000         5330 S 93RD PL       R1    NR   NR  RA
# 2  7HSE361  16-11-404-013-000         5410 S 93RD PL       R1    NR   NR  RA
# 3  7AEA310  23-31-416-001-000  11737   SEABISCUIT LN       R1    NR   NR  RA
# 4  7HST242  09-13-402-005-000        2421   RIDGE RD       R1  2022    6  RA
#
#   LandType Infl1 Infl2 V/I    SaleDate
# 0     RPIW     1    NC   I    5/5/2016
# 1     RPSW    NC     9   I    6/2/2022
# 2     RPIW    NC    NC   I  11/11/2021
# 3      RHS    NC    NC   I   6/25/2022
# 4     RPIW    NC    NC   I    6/1/2022

# %%
for col in str_df.columns:
    types = len(str_df[col].unique())
    if types < 100:
        one_hot_df = pd.get_dummies(str_df[col])
        str_df = str_df.join(one_hot_df)
        print(str_df.head())
# Out:
#       NBHD                PID                    Situs PrpCls  YrRD Remd Imp  \
# 0  7HST242  09-13-434-003-000        2525   RIDGE RD       R1    NR   NR  R2
# 1  7HSE361  16-11-404-012-000         5330 S 93RD PL       R1    NR   NR  RA
# 2  7HSE361  16-11-404-013-000         5410 S 93RD PL       R1    NR   NR  RA
# 3  7AEA310  23-31-416-001-000  11737   SEABISCUIT LN       R1    NR   NR  RA
# 4  7HST242  09-13-402-005-000        2421   RIDGE RD       R1  2022    6  RA
#
#   LandType Infl1 Infl2 V/I    SaleDate  R1
# 0     RPIW     1    NC   I    5/5/2016   1
# 1     RPSW    NC     9   I    6/2/2022   1
# 2     RPIW    NC    NC   I  11/11/2021   1
# 3      RHS    NC    NC   I   6/25/2022   1
# 4     RPIW    NC    NC   I    6/1/2022   1
#       NBHD                PID                    Situs PrpCls  YrRD Remd Imp  \
# 0  7HST242  09-13-434-003-000        2525   RIDGE RD       R1    NR   NR  R2
# 1  7HSE361  16-11-404-012-000         5330 S 93RD PL       R1    NR   NR  RA
# ...
